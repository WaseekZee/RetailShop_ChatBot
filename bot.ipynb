# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Shamlan
# [nltk_data]     Ahamed\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Shamlan
# [nltk_data]     Ahamed\AppData\Roaming\nltk_data...
# True

# %%
import mysql.connector

def create_connection():
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="Waseek@123",
        database="retailshop"
    )
    return connection

# %%
con = create_connection()

# %%
mycursor = con.cursor()

mycursor.execute("SELECT * FROM clothing")

cloths = mycursor.fetchall()

for cloth in cloths:
  print(cloths)
# Out:
# [(11, 'T-Shirt for Men', 2, 'Comfortable cotton t-shirt for men', Decimal('19.99'), 100, 2, datetime.date(2023, 10, 25)), (12, 'Summer Dress for Women', 2, 'Elegant summer dress with floral print', Decimal('29.99'), 50, 2, datetime.date(2023, 10, 25)), (13, 'Jeans for Men', 2, 'Slim-fit jeans for a stylish look', Decimal('39.99'), 75, 2, datetime.date(2023, 10, 25)), (14, 'Wool Sweater for Women', 2, 'Warm and cozy wool sweater', Decimal('49.99'), 40, 2, datetime.date(2023, 10, 25)), (15, 'Waterproof Jacket for Men', 2, 'Durable waterproof jacket', Decimal('69.99'), 30, 2, datetime.date(2023, 10, 25)), (16, 'A-line Skirt for Women', 2, 'Fashionable A-line skirt', Decimal('34.99'), 60, 2, datetime.date(2023, 10, 25)), (17, 'Cargo Shorts for Men', 2, 'Comfortable cargo shorts', Decimal('24.99'), 80, 2, datetime.date(2023, 10, 25)), (18, 'Silk Blouse for Women', 2, 'Elegant silk blouse', Decimal('54.99'), 45, 2, datetime.date(2023, 10, 25)), (19, 'Cotton Ankle Socks', 2, 'Soft cotton ankle socks', Decimal('6.99'), 200, 2, datetime.date(2023, 10, 25)), (20, 'Running Shoes for Men', 2, 'Durable running shoes', Decimal('79.99'), 25, 2, datetime.date(2023, 10, 25))]
# [(11, 'T-Shirt for Men', 2, 'Comfortable cotton t-shirt for men', Decimal('19.99'), 100, 2, datetime.date(2023, 10, 25)), (12, 'Summer Dress for Women', 2, 'Elegant summer dress with floral print', Decimal('29.99'), 50, 2, datetime.date(2023, 10, 25)), (13, 'Jeans for Men', 2, 'Slim-fit jeans for a stylish look', Decimal('39.99'), 75, 2, datetime.date(2023, 10, 25)), (14, 'Wool Sweater for Women', 2, 'Warm and cozy wool sweater', Decimal('49.99'), 40, 2, datetime.date(2023, 10, 25)), (15, 'Waterproof Jacket for Men', 2, 'Durable waterproof jacket', Decimal('69.99'), 30, 2, datetime.date(2023, 10, 25)), (16, 'A-line Skirt for Women', 2, 'Fashionable A-line skirt', Decimal('34.99'), 60, 2, datetime.date(2023, 10, 25)), (17, 'Cargo Shorts for Men', 2, 'Comfortable cargo shorts', Decimal('24.99'), 80, 2, datetime.date(2023, 10, 25)), (18, 'Silk Blouse for Women', 2, 'Elegant silk blouse', Decimal('54.99'), 45, 2, datetime.date(2023, 10, 25)), (19, 'Cotton Ankle Socks', 2, 'Soft cotton ankle socks', Decimal('6.99'), 200, 2, datetime.date(2023, 10, 25)), (20, 'Running Shoes for Men', 2, 'Durable running shoes', Decimal('79.99'), 25, 2, datetime.date(2023, 10, 25))]
# [(11, 'T-Shirt for Men', 2, 'Comfortable cotton t-shirt for men', Decimal('19.99'), 100, 2, datetime.date(2023, 10, 25)), (12, 'Summer Dress for Women', 2, 'Elegant summer dress with floral print', Decimal('29.99'), 50, 2, datetime.date(2023, 10, 25)), (13, 'Jeans for Men', 2, 'Slim-fit jeans for a stylish look', Decimal('39.99'), 75, 2, datetime.date(2023, 10, 25)), (14, 'Wool Sweater for Women', 2, 'Warm and cozy wool sweater', Decimal('49.99'), 40, 2, datetime.date(2023, 10, 25)), (15, 'Waterproof Jacket for Men', 2, 'Durable waterproof jacket', Decimal('69.99'), 30, 2, datetime.date(2023, 10, 25)), (16, 'A-line Skirt for Women', 2, 'Fashionable A-line skirt', Decimal('34.99'), 60, 2, datetime.date(2023, 10, 25)), (17, 'Cargo Shorts for Men', 2, 'Comfortable cargo shorts', Decimal('24.99'), 80, 2, datetime.date(2023, 10, 25)), (18, 'Silk Blouse for Women', 2, 'Elegant silk blouse', Decimal('54.99'), 45, 2, datetime.date(2023, 10, 25)), (19, 'Cotton Ankle Socks', 2, 'Soft cotton ankle socks', Decimal('6.99'), 200, 2, datetime.date(2023, 10, 25)), (20, 'Running Shoes for Men', 2, 'Durable running shoes', Decimal('79.99'), 25, 2, datetime.date(2023, 10, 25))]
# [(11, 'T-Shirt for Men', 2, 'Comfortable cotton t-shirt for men', Decimal('19.99'), 100, 2, datetime.date(2023, 10, 25)), (12, 'Summer Dress for Women', 2, 'Elegant summer dress with floral print', Decimal('29.99'), 50, 2, datetime.date(2023, 10, 25)), (13, 'Jeans for Men', 2, 'Slim-fit jeans for a stylish look', Decimal('39.99'), 75, 2, datetime.date(2023, 10, 25)), (14, 'Wool Sweater for Women', 2, 'Warm and cozy wool sweater', Decimal('49.99'), 40, 2, datetime.date(2023, 10, 25)), (15, 'Waterproof Jacket for Men', 2, 'Durable waterproof jacket', Decimal('69.99'), 30, 2, datetime.date(2023, 10, 25)), (16, 'A-line Skirt for Women', 2, 'Fashionable A-line skirt', Decimal('34.99'), 60, 2, datetime.date(2023, 10, 25)), (17, 'Cargo Shorts for Men', 2, 'Comfortable cargo shorts', Decimal('24.99'), 80, 2, datetime.date(2023, 10, 25)), (18, 'Silk Blouse for Women', 2, 'Elegant silk blouse', Decimal('54.99'), 45, 2, datetime.date(2023, 10, 25)), (19, 'Cotton Ankle Socks', 2, 'Soft cotton ankle socks', Decimal('6.99'), 200, 2, datetime.date(2023, 10, 25)), (20, 'Running Shoes for Men', 2, 'Durable running shoes', Decimal('79.99'), 25, 2, datetime.date(2023, 10, 25))]
# [(11, 'T-Shirt for Men', 2, 'Comfortable cotton t-shirt for men', Decimal('19.99'), 100, 2, datetime.date(2023, 10, 25)), (12, 'Summer Dress for Women', 2, 'Elegant summer dress with floral print', Decimal('29.99'), 50, 2, datetime.date(2023, 10, 25)), (13, 'Jeans for Men', 2, 'Slim-fit jeans for a stylish look', Decimal('39.99'), 75, 2, datetime.date(2023, 10, 25)), (14, 'Wool Sweater for Women', 2, 'Warm and cozy wool sweater', Decimal('49.99'), 40, 2, datetime.date(2023, 10, 25)), (15, 'Waterproof Jacket for Men', 2, 'Durable waterproof jacket', Decimal('69.99'), 30, 2, datetime.date(2023, 10, 25)), (16, 'A-line Skirt for Women', 2, 'Fashionable A-line skirt', Decimal('34.99'), 60, 2, datetime.date(2023, 10, 25)), (17, 'Cargo Shorts for Men', 2, 'Comfortable cargo shorts', Decimal('24.99'), 80, 2, datetime.date(2023, 10, 25)), (18, 'Silk Blouse for Women', 2, 'Elegant silk blouse', Decimal('54.99'), 45, 2, datetime.date(2023, 10, 25)), (19, 'Cotton Ankle Socks', 2, 'Soft cotton ankle socks', Decimal('6.99'), 200, 2, datetime.date(2023, 10, 25)), (20, 'Running Shoes for Men', 2, 'Durable running shoes', Decimal('79.99'), 25, 2, datetime.date(2023, 10, 25))]
# [(11, 'T-Shirt for Men', 2, 'Comfortable cotton t-shirt for men', Decimal('19.99'), 100, 2, datetime.date(2023, 10, 25)), (12, 'Summer Dress for Women', 2, 'Elegant summer dress with floral print', Decimal('29.99'), 50, 2, datetime.date(2023, 10, 25)), (13, 'Jeans for Men', 2, 'Slim-fit jeans for a stylish look', Decimal('39.99'), 75, 2, datetime.date(2023, 10, 25)), (14, 'Wool Sweater for Women', 2, 'Warm and cozy wool sweater', Decimal('49.99'), 40, 2, datetime.date(2023, 10, 25)), (15, 'Waterproof Jacket for Men', 2, 'Durable waterproof jacket', Decimal('69.99'), 30, 2, datetime.date(2023, 10, 25)), (16, 'A-line Skirt for Women', 2, 'Fashionable A-line skirt', Decimal('34.99'), 60, 2, datetime.date(2023, 10, 25)), (17, 'Cargo Shorts for Men', 2, 'Comfortable cargo shorts', Decimal('24.99'), 80, 2, datetime.date(2023, 10, 25)), (18, 'Silk Blouse for Women', 2, 'Elegant silk blouse', Decimal('54.99'), 45, 2, datetime.date(2023, 10, 25)), (19, 'Cotton Ankle Socks', 2, 'Soft cotton ankle socks', Decimal('6.99'), 200, 2, datetime.date(2023, 10, 25)), (20, 'Running Shoes for Men', 2, 'Durable running shoes', Decimal('79.99'), 25, 2, datetime.date(2023, 10, 25))]
# [(11, 'T-Shirt for Men', 2, 'Comfortable cotton t-shirt for men', Decimal('19.99'), 100, 2, datetime.date(2023, 10, 25)), (12, 'Summer Dress for Women', 2, 'Elegant summer dress with floral print', Decimal('29.99'), 50, 2, datetime.date(2023, 10, 25)), (13, 'Jeans for Men', 2, 'Slim-fit jeans for a stylish look', Decimal('39.99'), 75, 2, datetime.date(2023, 10, 25)), (14, 'Wool Sweater for Women', 2, 'Warm and cozy wool sweater', Decimal('49.99'), 40, 2, datetime.date(2023, 10, 25)), (15, 'Waterproof Jacket for Men', 2, 'Durable waterproof jacket', Decimal('69.99'), 30, 2, datetime.date(2023, 10, 25)), (16, 'A-line Skirt for Women', 2, 'Fashionable A-line skirt', Decimal('34.99'), 60, 2, datetime.date(2023, 10, 25)), (17, 'Cargo Shorts for Men', 2, 'Comfortable cargo shorts', Decimal('24.99'), 80, 2, datetime.date(2023, 10, 25)), (18, 'Silk Blouse for Women', 2, 'Elegant silk blouse', Decimal('54.99'), 45, 2, datetime.date(2023, 10, 25)), (19, 'Cotton Ankle Socks', 2, 'Soft cotton ankle socks', Decimal('6.99'), 200, 2, datetime.date(2023, 10, 25)), (20, 'Running Shoes for Men', 2, 'Durable running shoes', Decimal('79.99'), 25, 2, datetime.date(2023, 10, 25))]
# [(11, 'T-Shirt for Men', 2, 'Comfortable cotton t-shirt for men', Decimal('19.99'), 100, 2, datetime.date(2023, 10, 25)), (12, 'Summer Dress for Women', 2, 'Elegant summer dress with floral print', Decimal('29.99'), 50, 2, datetime.date(2023, 10, 25)), (13, 'Jeans for Men', 2, 'Slim-fit jeans for a stylish look', Decimal('39.99'), 75, 2, datetime.date(2023, 10, 25)), (14, 'Wool Sweater for Women', 2, 'Warm and cozy wool sweater', Decimal('49.99'), 40, 2, datetime.date(2023, 10, 25)), (15, 'Waterproof Jacket for Men', 2, 'Durable waterproof jacket', Decimal('69.99'), 30, 2, datetime.date(2023, 10, 25)), (16, 'A-line Skirt for Women', 2, 'Fashionable A-line skirt', Decimal('34.99'), 60, 2, datetime.date(2023, 10, 25)), (17, 'Cargo Shorts for Men', 2, 'Comfortable cargo shorts', Decimal('24.99'), 80, 2, datetime.date(2023, 10, 25)), (18, 'Silk Blouse for Women', 2, 'Elegant silk blouse', Decimal('54.99'), 45, 2, datetime.date(2023, 10, 25)), (19, 'Cotton Ankle Socks', 2, 'Soft cotton ankle socks', Decimal('6.99'), 200, 2, datetime.date(2023, 10, 25)), (20, 'Running Shoes for Men', 2, 'Durable running shoes', Decimal('79.99'), 25, 2, datetime.date(2023, 10, 25))]
# [(11, 'T-Shirt for Men', 2, 'Comfortable cotton t-shirt for men', Decimal('19.99'), 100, 2, datetime.date(2023, 10, 25)), (12, 'Summer Dress for Women', 2, 'Elegant summer dress with floral print', Decimal('29.99'), 50, 2, datetime.date(2023, 10, 25)), (13, 'Jeans for Men', 2, 'Slim-fit jeans for a stylish look', Decimal('39.99'), 75, 2, datetime.date(2023, 10, 25)), (14, 'Wool Sweater for Women', 2, 'Warm and cozy wool sweater', Decimal('49.99'), 40, 2, datetime.date(2023, 10, 25)), (15, 'Waterproof Jacket for Men', 2, 'Durable waterproof jacket', Decimal('69.99'), 30, 2, datetime.date(2023, 10, 25)), (16, 'A-line Skirt for Women', 2, 'Fashionable A-line skirt', Decimal('34.99'), 60, 2, datetime.date(2023, 10, 25)), (17, 'Cargo Shorts for Men', 2, 'Comfortable cargo shorts', Decimal('24.99'), 80, 2, datetime.date(2023, 10, 25)), (18, 'Silk Blouse for Women', 2, 'Elegant silk blouse', Decimal('54.99'), 45, 2, datetime.date(2023, 10, 25)), (19, 'Cotton Ankle Socks', 2, 'Soft cotton ankle socks', Decimal('6.99'), 200, 2, datetime.date(2023, 10, 25)), (20, 'Running Shoes for Men', 2, 'Durable running shoes', Decimal('79.99'), 25, 2, datetime.date(2023, 10, 25))]
# [(11, 'T-Shirt for Men', 2, 'Comfortable cotton t-shirt for men', Decimal('19.99'), 100, 2, datetime.date(2023, 10, 25)), (12, 'Summer Dress for Women', 2, 'Elegant summer dress with floral print', Decimal('29.99'), 50, 2, datetime.date(2023, 10, 25)), (13, 'Jeans for Men', 2, 'Slim-fit jeans for a stylish look', Decimal('39.99'), 75, 2, datetime.date(2023, 10, 25)), (14, 'Wool Sweater for Women', 2, 'Warm and cozy wool sweater', Decimal('49.99'), 40, 2, datetime.date(2023, 10, 25)), (15, 'Waterproof Jacket for Men', 2, 'Durable waterproof jacket', Decimal('69.99'), 30, 2, datetime.date(2023, 10, 25)), (16, 'A-line Skirt for Women', 2, 'Fashionable A-line skirt', Decimal('34.99'), 60, 2, datetime.date(2023, 10, 25)), (17, 'Cargo Shorts for Men', 2, 'Comfortable cargo shorts', Decimal('24.99'), 80, 2, datetime.date(2023, 10, 25)), (18, 'Silk Blouse for Women', 2, 'Elegant silk blouse', Decimal('54.99'), 45, 2, datetime.date(2023, 10, 25)), (19, 'Cotton Ankle Socks', 2, 'Soft cotton ankle socks', Decimal('6.99'), 200, 2, datetime.date(2023, 10, 25)), (20, 'Running Shoes for Men', 2, 'Durable running shoes', Decimal('79.99'), 25, 2, datetime.date(2023, 10, 25))]

# %%
# importing the required modules. 
import random 
import json 
import pickle 
import numpy as np 
import nltk 

from keras.models import Sequential 
from nltk.stem import WordNetLemmatizer 
from keras.layers import Dense, Activation, Dropout 
from keras.optimizers import SGD 


lemmatizer = WordNetLemmatizer() 

# reading the json.intense file 
intents = json.loads(open("intents.json").read()) 

# creating empty lists to store data 
words = [] 
classes = [] 
documents = [] 
ignore_letters = ["?", "!", ".", ","] 
for intent in intents['intents']: 
	for pattern in intent['patterns']: 
		# separating words from patterns 
		word_list = nltk.word_tokenize(pattern) 
		words.extend(word_list) # and adding them to words list 
		
		# associating patterns with respective tags 
		documents.append(((word_list), intent['tag'])) 

		# appending the tags to the class list 
		if intent['tag'] not in classes: 
			classes.append(intent['tag']) 

# storing the root words or lemma 
words = [lemmatizer.lemmatize(word) 
		for word in words if word not in ignore_letters] 
words = sorted(set(words)) 

# saving the words and classes list to binary files 
pickle.dump(words, open('words.pkl', 'wb')) 
pickle.dump(classes, open('classes.pkl', 'wb'))

# %%
# we need numerical values of the 
# words because a neural network 
# needs numerical values to work with 
training = [] 
output_empty = [0]*len(classes) 
for document in documents: 
	bag = [] 
	word_patterns = document[0] 
	word_patterns = [lemmatizer.lemmatize( 
		word.lower()) for word in word_patterns] 
	for word in words: 
		bag.append(1) if word in word_patterns else bag.append(0) 
		
	# making a copy of the output_empty 
	output_row = list(output_empty) 
	output_row[classes.index(document[1])] = 1
	training.append([bag, output_row]) 
random.shuffle(training) 
training = np.asarray(training, dtype ="object" ) 

# splitting the data 
train_x = list(training[:, 0]) 
train_y = list(training[:, 1])

# %%
# creating a Sequential machine learning model 
model = Sequential() 
model.add(Dense(128, input_shape=(len(train_x[0]), ), 
				activation='relu')) 
model.add(Dropout(0.5)) 
model.add(Dense(64, activation='relu')) 
model.add(Dropout(0.5)) 
model.add(Dense(len(train_y[0]), 
				activation='softmax')) 

# compiling the model 
model.compile(loss='categorical_crossentropy', 
			optimizer='adam', metrics=['accuracy']) 
hist = model.fit(np.array(train_x), np.array(train_y), 
				epochs=200, batch_size=5, verbose=1) 

# saving the model 
model.save("chatbotmodel.h5", hist) 

# print statement to show the 
# successful training of the Chatbot model 
print("Yay!")
# Out:
# Epoch 1/200
# 50/50 [==============================] - 1s 2ms/step - loss: 4.3227 - accuracy: 0.0203
# Epoch 2/200
# 50/50 [==============================] - 0s 2ms/step - loss: 4.2783 - accuracy: 0.0285
# Epoch 3/200
# 50/50 [==============================] - 0s 2ms/step - loss: 4.2428 - accuracy: 0.0407
# Epoch 4/200
# 50/50 [==============================] - 0s 2ms/step - loss: 4.1944 - accuracy: 0.0366
# Epoch 5/200
# 50/50 [==============================] - 0s 2ms/step - loss: 4.1540 - accuracy: 0.0569
# Epoch 6/200
# 50/50 [==============================] - 0s 2ms/step - loss: 4.0927 - accuracy: 0.0650
# Epoch 7/200
# 50/50 [==============================] - 0s 2ms/step - loss: 3.9799 - accuracy: 0.0813
# Epoch 8/200
# 50/50 [==============================] - 0s 2ms/step - loss: 3.8891 - accuracy: 0.1016
# Epoch 9/200
# 50/50 [==============================] - 0s 2ms/step - loss: 3.7659 - accuracy: 0.1382
# Epoch 10/200
# 50/50 [==============================] - 0s 2ms/step - loss: 3.6408 - accuracy: 0.1992
# Epoch 11/200
# 50/50 [==============================] - 0s 2ms/step - loss: 3.5110 - accuracy: 0.1707
# Epoch 12/200
# 50/50 [==============================] - 0s 2ms/step - loss: 3.2867 - accuracy: 0.2805
# Epoch 13/200
# 50/50 [==============================] - 0s 2ms/step - loss: 3.1952 - accuracy: 0.2642
# Epoch 14/200
# 50/50 [==============================] - 0s 2ms/step - loss: 3.0279 - accuracy: 0.3211
# Epoch 15/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.8391 - accuracy: 0.3293
# Epoch 16/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.6816 - accuracy: 0.3618
# Epoch 17/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.5738 - accuracy: 0.3699
# Epoch 18/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.4612 - accuracy: 0.4146
# Epoch 19/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.2861 - accuracy: 0.4390
# Epoch 20/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.1895 - accuracy: 0.4350
# Epoch 21/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.1508 - accuracy: 0.4553
# Epoch 22/200
# 50/50 [==============================] - 0s 2ms/step - loss: 2.1307 - accuracy: 0.4431
# Epoch 23/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.9937 - accuracy: 0.5000
# Epoch 24/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.8164 - accuracy: 0.5813
# Epoch 25/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.8518 - accuracy: 0.5366
# Epoch 26/200
# 50/50 [==============================] - 0s 3ms/step - loss: 1.6881 - accuracy: 0.5976
# Epoch 27/200
# 50/50 [==============================] - 0s 3ms/step - loss: 1.5901 - accuracy: 0.6220
# Epoch 28/200
# 50/50 [==============================] - 0s 3ms/step - loss: 1.5942 - accuracy: 0.6179
# Epoch 29/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.6517 - accuracy: 0.6016
# Epoch 30/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.4660 - accuracy: 0.6301
# Epoch 31/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.5318 - accuracy: 0.5894
# Epoch 32/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.3657 - accuracy: 0.6423
# Epoch 33/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.3533 - accuracy: 0.6382
# Epoch 34/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.3500 - accuracy: 0.6667
# Epoch 35/200
# 50/50 [==============================] - 0s 3ms/step - loss: 1.4068 - accuracy: 0.6220
# Epoch 36/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.3715 - accuracy: 0.6545
# Epoch 37/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.3535 - accuracy: 0.6301
# Epoch 38/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.1615 - accuracy: 0.6829
# Epoch 39/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.2015 - accuracy: 0.6545
# Epoch 40/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.1541 - accuracy: 0.6626
# Epoch 41/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.0991 - accuracy: 0.7317
# Epoch 42/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.1147 - accuracy: 0.6911
# Epoch 43/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.0586 - accuracy: 0.7073
# Epoch 44/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.0950 - accuracy: 0.7073
# Epoch 45/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9839 - accuracy: 0.7683
# Epoch 46/200
# 50/50 [==============================] - 0s 2ms/step - loss: 1.0917 - accuracy: 0.6707
# Epoch 47/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9434 - accuracy: 0.7398
# Epoch 48/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9750 - accuracy: 0.7114
# Epoch 49/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9856 - accuracy: 0.7195
# Epoch 50/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9010 - accuracy: 0.7642
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9765 - accuracy: 0.7236
# Epoch 52/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9477 - accuracy: 0.7114
# Epoch 53/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7850 - accuracy: 0.8089
# Epoch 54/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8436 - accuracy: 0.7805
# Epoch 55/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7644 - accuracy: 0.7846
# Epoch 56/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8261 - accuracy: 0.7480
# Epoch 57/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8033 - accuracy: 0.7642
# Epoch 58/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7473 - accuracy: 0.8089
# Epoch 59/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8009 - accuracy: 0.7561
# Epoch 60/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7127 - accuracy: 0.8293
# Epoch 61/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7499 - accuracy: 0.8008
# Epoch 62/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6876 - accuracy: 0.7805
# Epoch 63/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7212 - accuracy: 0.8008
# Epoch 64/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7411 - accuracy: 0.8089
# Epoch 65/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7357 - accuracy: 0.7846
# Epoch 66/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7713 - accuracy: 0.7724
# Epoch 67/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6720 - accuracy: 0.8374
# Epoch 68/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7486 - accuracy: 0.7642
# Epoch 69/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7014 - accuracy: 0.7927
# Epoch 70/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7025 - accuracy: 0.7805
# Epoch 71/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5881 - accuracy: 0.8130
# Epoch 72/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7577 - accuracy: 0.7886
# Epoch 73/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6200 - accuracy: 0.8171
# Epoch 74/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6221 - accuracy: 0.8089
# Epoch 75/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7029 - accuracy: 0.7724
# Epoch 76/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6582 - accuracy: 0.7846
# Epoch 77/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5777 - accuracy: 0.8171
# Epoch 78/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5873 - accuracy: 0.8252
# Epoch 79/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6912 - accuracy: 0.7683
# Epoch 80/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6074 - accuracy: 0.8089
# Epoch 81/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6169 - accuracy: 0.8049
# Epoch 82/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6572 - accuracy: 0.8049
# Epoch 83/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6037 - accuracy: 0.8293
# Epoch 84/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6286 - accuracy: 0.8455
# Epoch 85/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5714 - accuracy: 0.8455
# Epoch 86/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6525 - accuracy: 0.7927
# Epoch 87/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5676 - accuracy: 0.8211
# Epoch 88/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5407 - accuracy: 0.8252
# Epoch 89/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5132 - accuracy: 0.8455
# Epoch 90/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5502 - accuracy: 0.8293
# Epoch 91/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5019 - accuracy: 0.8333
# Epoch 92/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5014 - accuracy: 0.8496
# Epoch 93/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6006 - accuracy: 0.8211
# Epoch 94/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5325 - accuracy: 0.8496
# Epoch 95/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6160 - accuracy: 0.8293
# Epoch 96/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5971 - accuracy: 0.8252
# Epoch 97/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4891 - accuracy: 0.8496
# Epoch 98/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4933 - accuracy: 0.8496
# Epoch 99/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5529 - accuracy: 0.8333
# Epoch 100/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4893 - accuracy: 0.8699
# Epoch 101/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5393 - accuracy: 0.8211
# Epoch 102/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5424 - accuracy: 0.8049
# Epoch 103/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4630 - accuracy: 0.8618
# Epoch 104/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6133 - accuracy: 0.8293
# Epoch 105/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4943 - accuracy: 0.8496
# Epoch 106/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4441 - accuracy: 0.8333
# Epoch 107/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5249 - accuracy: 0.8374
# Epoch 108/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5423 - accuracy: 0.8252
# Epoch 109/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4862 - accuracy: 0.8333
# Epoch 110/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4555 - accuracy: 0.8577
# Epoch 111/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5628 - accuracy: 0.8171
# Epoch 112/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4552 - accuracy: 0.8537
# Epoch 113/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4867 - accuracy: 0.8415
# Epoch 114/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4682 - accuracy: 0.8659
# Epoch 115/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4902 - accuracy: 0.8537
# Epoch 116/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3883 - accuracy: 0.8943
# Epoch 117/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3830 - accuracy: 0.8699
# Epoch 118/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4376 - accuracy: 0.8577
# Epoch 119/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8821
# Epoch 120/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8618
# Epoch 121/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5104 - accuracy: 0.8252
# Epoch 122/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4086 - accuracy: 0.8537
# Epoch 123/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8740
# Epoch 124/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.8333
# Epoch 125/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4401 - accuracy: 0.8618
# Epoch 126/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4264 - accuracy: 0.8618
# Epoch 127/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3760 - accuracy: 0.8943
# Epoch 128/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.9024
# Epoch 129/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.8943
# Epoch 130/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4419 - accuracy: 0.8577
# Epoch 131/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8577
# Epoch 132/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3878 - accuracy: 0.8618
# Epoch 133/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4528 - accuracy: 0.8618
# Epoch 134/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8699
# Epoch 135/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3737 - accuracy: 0.8780
# Epoch 136/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8740
# Epoch 137/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3546 - accuracy: 0.8902
# Epoch 138/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4509 - accuracy: 0.8577
# Epoch 139/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3591 - accuracy: 0.8943
# Epoch 140/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8740
# Epoch 141/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3554 - accuracy: 0.8862
# Epoch 142/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4023 - accuracy: 0.8821
# Epoch 143/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3872 - accuracy: 0.8415
# Epoch 144/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4135 - accuracy: 0.8618
# Epoch 145/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4183 - accuracy: 0.8699
# Epoch 146/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3166 - accuracy: 0.8984
# Epoch 147/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3533 - accuracy: 0.8984
# Epoch 148/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3790 - accuracy: 0.8659
# Epoch 149/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3244 - accuracy: 0.8902
# Epoch 150/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4264 - accuracy: 0.8537
# Epoch 151/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3551 - accuracy: 0.8821
# Epoch 152/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.8984
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8902
# Epoch 154/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4104 - accuracy: 0.8537
# Epoch 155/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3656 - accuracy: 0.8740
# Epoch 156/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4104 - accuracy: 0.8455
# Epoch 157/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3514 - accuracy: 0.8618
# Epoch 158/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3711 - accuracy: 0.8780
# Epoch 159/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4188 - accuracy: 0.8537
# Epoch 160/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3409 - accuracy: 0.8821
# Epoch 161/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3888 - accuracy: 0.8659
# Epoch 162/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8740
# Epoch 163/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3613 - accuracy: 0.9024
# Epoch 164/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3524 - accuracy: 0.8740
# Epoch 165/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3762 - accuracy: 0.8699
# Epoch 166/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3587 - accuracy: 0.8821
# Epoch 167/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3497 - accuracy: 0.8902
# Epoch 168/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4281 - accuracy: 0.8577
# Epoch 169/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8537
# Epoch 170/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2911 - accuracy: 0.9146
# Epoch 171/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3836 - accuracy: 0.8780
# Epoch 172/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4109 - accuracy: 0.8618
# Epoch 173/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8618
# Epoch 174/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4263 - accuracy: 0.8618
# Epoch 175/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3736 - accuracy: 0.8943
# Epoch 176/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3831 - accuracy: 0.8780
# Epoch 177/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3476 - accuracy: 0.8902
# Epoch 178/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8699
# Epoch 179/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3388 - accuracy: 0.8821
# Epoch 180/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2984 - accuracy: 0.9065
# Epoch 181/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4093 - accuracy: 0.8455
# Epoch 182/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.8821
# Epoch 183/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2943 - accuracy: 0.8943
# Epoch 184/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3061 - accuracy: 0.9065
# Epoch 185/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3782 - accuracy: 0.8780
# Epoch 186/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3656 - accuracy: 0.8740
# Epoch 187/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2807 - accuracy: 0.9065
# Epoch 188/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3149 - accuracy: 0.8984
# Epoch 189/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3299 - accuracy: 0.8902
# Epoch 190/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8699
# Epoch 191/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2942 - accuracy: 0.9106
# Epoch 192/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3100 - accuracy: 0.9106
# Epoch 193/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3249 - accuracy: 0.8943
# Epoch 194/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3141 - accuracy: 0.8902
# Epoch 195/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3950 - accuracy: 0.8780
# Epoch 196/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2627 - accuracy: 0.9024
# Epoch 197/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2634 - accuracy: 0.9146
# Epoch 198/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2198 - accuracy: 0.9106
# Epoch 199/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3637 - accuracy: 0.8618
# Epoch 200/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3323 - accuracy: 0.8740
# Yay!

# %%
# required modules 
import random 
import json 
import pickle 
import numpy as np 
import nltk 
from keras.models import load_model 
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer() 

# loading the files we made previously 
intents = json.loads(open("intents.json").read()) 
words = pickle.load(open('words.pkl', 'rb')) 
classes = pickle.load(open('classes.pkl', 'rb')) 
model = load_model('chatbotmodel.h5')

# %%
def clean_up_sentences(sentence): 
	sentence_words = nltk.word_tokenize(sentence) 
	sentence_words = [lemmatizer.lemmatize(word) 
					for word in sentence_words] 
	return sentence_words

# %%
def bagw(sentence): 
	
	# separate out words from the input sentence 
	sentence_words = clean_up_sentences(sentence) 
	bag = [0]*len(words) 
	for w in sentence_words: 
		for i, word in enumerate(words): 

			# check whether the word 
			# is present in the input as well 
			if word == w: 

				# as the list of words 
				# created earlier. 
				bag[i] = 1

	# return a numpy array 
	return np.array(bag)

# %%
def predict_class(sentence): 
	bow = bagw(sentence) 
	res = model.predict(np.array([bow]))[0] 
	ERROR_THRESHOLD = 0.25
	results = [[i, r] for i, r in enumerate(res) 
			if r > ERROR_THRESHOLD] 
	results.sort(key=lambda x: x[1], reverse=True) 
	return_list = [] 
	for r in results: 
		return_list.append({'intent': classes[r[0]], 
							'probability': str(r[1])}) 
		return return_list

# %%
def get_response(intents_list, intents_json): 
	tag = intents_list[0]['intent'] 
	list_of_intents = intents_json['intents'] 
	result = "" 
	for i in list_of_intents: 
		if i['tag'] == tag: 
			
			# prints a random response 
			result = random.choice(i['responses']) 
			break
	return result 

print("Chatbot is up!")
# Out:
# Chatbot is up!

# %%
while True: 
	message = input("") 
	ints = predict_class(message) 
	res = get_response(ints, intents) 
	print(res)
# Out:
# hi
# 1/1 [==============================] - 0s 66ms/step
# Hello
# products
# 1/1 [==============================] - 0s 8ms/step
# Limited edition items are unique and available for a short period. Don't miss out on these special products. Check our 'Limited Edition' section.
# what products do yuhave
# 1/1 [==============================] - 0s 17ms/step
# Stay in the loop with our latest arrivals on our website or by stopping by our store.
